# %%
a=[10,20,30,40]

# %%
for i in a:
    print(i,end=' ')
# Out:
# 10 20 30 40

# %%
for i in a:
    if i==10:
        print("value found")
        break
else:
     print("value not found")
# Out:
# value found

# %%
40 in a
# Out:
# True

# %%
for i in range(len(a)):
    if a[i]==30:
        print(i)
        break
# Out:
# 2

# %%
iteams=[10,20,30,50,60,70,80]

# %%
iteams=[10,20,30,50,60,70,80]
print(iteams.index(80))
# Out:
# 6

# %%
list_1=[20,1,2,5,58,5,2,5,8,5,5,2,45,]

# %%
list_1[-len]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 list_1[-len]
#
# TypeError: bad operand type for unary -: 'builtin_function_or_method'

# %%
information=[1,'abc',84.9,'a']
print(information)
# Out:
# [1, 'abc', 84.9, 'a']

# %%
information[1]
# Out:
# 'abc'

# %%
information.append('bujji')
print(information)
# Out:
# [1, 'abc', 84.9, 'a', 'b', 'u', 'j', 'j', 'i', 'bujji', 'bujji']

# %%
information*2
# Out:
# [1,
#  'abc',
#  84.9,
#  'a',
#  'b',
#  'u',
#  'j',
#  'j',
#  'i',
#  'bujji',
#  'bujji',
#  1,
#  'abc',
#  84.9,
#  'a',
#  'b',
#  'u',
#  'j',
#  'j',
#  'i',
#  'bujji',
#  'bujji']

# %%
information
# Out:
# [1, 'abc', 84.9, 'a', 'b', 'u', 'j', 'j', 'i', 'bujji', 'bujji']

# %%
information[1]= "xyz"

# %%
information
# Out:
# [1, 'xyz', 84.9, 'a', 'b', 'u', 'j', 'j', 'i', 'bujji', 'bujji']

# %%
information [0:3]
# Out:
# [1, 'xyz', 84.9]

# %%
student_2=["stu",8.58,"female","9036778093"]

# %%
student_2[::-3]
# Out:
# ['9036778093', 'stu']

# %%
student_2[::2]
# Out:
# ['stu', 'female']

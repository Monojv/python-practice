# %%
a=20
b=30
a,b=b,a
print(a)
print(b)
# Out:
# 30
# 20

# %%
a=10
b=20
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# a= 20
# b= 10

# %%
a=10
b=20
temp=a
a=b
b=temp
print("a=",a)
print("a=",b)
# Out:
# a= 20
# a= 10

# %%
a=10
b=20
a=a+b
b=a-b
a=a-b
print("a=",a)
print("b=",b)
# Out:
# a= 20
# b= 10

# %%
a=10
b=20
a=a^b
b=a^b
a=a^b
print("a=",a)
print("b=",a)
# Out:
# a= 20
# b= 20

# %%
a=10
b=20
a=a*b
b=a/b
a=a//b
print("a=",a)
print("b=",b)
# Out:
# a= 20.0
# b= 10.0

# %%
x1=float(input())
x2=float(input())
y1=float(input())
y2=float(input())
s=(x1+x2)/2,(y1+y2)/2
print(s)
# Out:
#  2
#  4
#  10
#  15
# (3.0, 12.5)

# %%
weight=float(input())
height=float(input())
BMI=(weight/height**2)
print(BMI)
# Out:
#  50
#  1.6
# 19.531249999999996

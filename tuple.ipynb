# %%
empty_tuple=()
print(empty_tuple)
# Out:
# ()

# %%
value_tuple=23,45,66
print(value_tuple)
# Out:
# (23, 45, 66)

# %%
value_tuple=23,45,"bujji"
print(value_tuple)
# Out:
# (23, 45, 'bujji')

# %%
tuple=('bujji')
print(tuple)
# Out:
# bujji

# %%
tuple=('bujji',)
print(tuple)
# Out:
# ('bujji',)

# %%
value_tuple(25,45,'bujji')
value_tuple[1]=7
print(value_tuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 value_tuple(25,45,'bujji')
#       2 value_tuple[1]=7
#       3 print(value_tuple)
#
# NameError: name 'value_tuple' is not defined

# %%
value1_tuple=(26,25,'bujji')
value2_tuple=(7,5.6,"nisha")
print(value1_tuple+value2_tuple)
# Out:
# (26, 25, 'bujji', 7, 5.6, 'nisha')

# %%
value1_tuple=(26,25,'bujji')
value2_tuple=(7,5.6,"nisha")
print(value2_tuple+value1_tuple)
# Out:
# (7, 5.6, 'nisha', 26, 25, 'bujji')

# %%
value1_tuple=(26,25,'bujji')
value2_tuple=(7,5.6,"nisha")
value3_tuple=value1_tuple,value2_tuple
print(value3_tuple)
# Out:
# ((26, 25, 'bujji'), (7, 5.6, 'nisha'))

# %%
value_tuple=(25,45,'bujji i love u')*2
print(value_tuple)
# Out:
# (25, 45, 'bujji i love u', 25, 45, 'bujji i love u')

# %%
value_tuple=(26,45,'bujji',7.5)
print(value_tuple[3])
# Out:
# 7.5

# %%
value_tuple=(26,45,'bujji',7.5)
print(value_tuple[0:])
# Out:
# (26, 45, 'bujji', 7.5)

# %%
value_tuple=(26,45,'bujji',7.5)
print(value_tuple[2:])
# Out:
# ('bujji', 7.5)

# %%
value_tuple=(26,45,'bujji',7.5)
print(value_tuple[2])
# Out:
# bujji

# %%
value_tuple=(26,45,'bujji',7.5)
print(value_tuple[:3])
# Out:
# (26, 45, 'bujji')

# %%
value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
print(value_tuple[:7])
# Out:
# (26, 45, 'bujji', 7.5, 'z', 5, 6.9)

# %%
value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
print(value_tuple[-1])
# Out:
# 6.9

# %%
value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
print(value_tuple[:-4])
# Out:
# (26, 45, 'bujji')

# %%
value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
print(value_tuple[:-1])
# Out:
# (26, 45, 'bujji', 7.5, 'z', 5)

# %%
value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
print(value_tuple[::-1])
# Out:
# (6.9, 5, 'z', 7.5, 'bujji', 45, 26)

# %%
value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
print(value_tuple[::2])
# Out:
# (26, 'bujji', 'z', 6.9)

# %%
value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
print(value_tuple[:7])
# Out:
# (26, 45, 'bujji', 7.5, 'z', 5, 6.9)

# %%
value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
print(value_tuple[1:6:2])
# Out:
# (45, 7.5, 5)

# %%
value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
del(value_tuple[1])
print(value_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
# ----> 2 del(value_tuple[1])
#       3 print(value_tuple)
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
value_tuple=(26,45,'bujji',7.5,'z',5,6.9)
print(value_tuple[1])
# Out:
# 45

# %%
tuple=('bujji')
n=3
for i in range(int(n)):
   tuple=(tuple,)
   print(tuple)
# Out:
# ('bujji',)
# (('bujji',),)
# ((('bujji',),),)

# %%
tuple=('developer',5,8.9,'r',8)
print(len(tuple))
# Out:
# 5

# %%
tuple=(9,5,89,4,8)
print(sorted(tuple))
# Out:
# [4, 5, 8, 9, 89]

# %%
tuple=(0,1)
print(any(tuple))
# Out:
# True

# %%
tuple=(0,1)
print(any(tuple))
# Out:
# True

# %%
tuple=(4,1)
print(all(tuple))
# Out:
# True

# %%
tuple=(0,1)
print(any(tuple))
tuple=(0,5,7)
# Out:
# True

# %%
tuple=(3,7,'p','y','z',9.5,'y')
print(tuple.index('y'))
print(tuple.index(7))
# Out:
# 3
# 1

# %%
empty_tuple=()
print(empty_tuple)
# Out:
# ()

# %%
value_tuple=26,45,32
print(value_tuple)
# Out:
# (26, 45, 32)

# %%
value_tuple=(26,45,'hello bae')
print(value_tuple)
# Out:
# (26, 45, 'hello bae')

# %%
tuple=('hello',)
print(tuple)
# Out:
# ('hello',)

# %%
value_tuple=(26,45,'hello bae')
value_tuple[i]=7
print(value_tuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 value_tuple=(26,45,'hello bae')
# ----> 2 value_tuple[i]=7
#       3 print(value_tuple)
#
# NameError: name 'i' is not defined

# %%
value1_tuple=(26,45,'hello bae')
value2_tuple=7,5.6,"python"
print(value1_tuple+value2_tuple)
# Out:
# (26, 45, 'hello bae', 7, 5.6, 'python')

# %%
value1_tuple=(26,45,'hello bae')
value2_tuple=7,5.6,"python"
value3_tuple= value1_tuple.value2_tuple
print(value3_tuple)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 3
#       1 value1_tuple=(26,45,'hello bae')
#       2 value2_tuple=7,5.6,"python"
# ----> 3 value3_tuple= value1_tuple.value2_tuple
#       4 print(value3_tuple)
#
# AttributeError: 'tuple' object has no attribute 'value2_tuple'

# %%
value_tuple=(26,45,'hello',7.5)
print(value_tuple[3])
# Out:
# 7.5

# %%
value_tuple=(26,45,'hello',7.5)
print(value_tuple[0:])
# Out:
# (26, 45, 'hello', 7.5)

# %%
value_tuple=(26,45,'hello',7.5)
print(value_tuple[2:])
# Out:
# ('hello', 7.5)

# %%
value_tuple=(26,45,'hello',7.5)
print(value_tuple[:3])
# Out:
# (26, 45, 'hello')

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[:7])
# Out:
# (26, 45, 'hello', 7.5, 'x', 5, 6.9)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[:4])
# Out:
# (26, 45, 'hello', 7.5)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[-1])
# Out:
# 6.9

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[:-4])
# Out:
# (26, 45, 'hello')

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[-4:])
# Out:
# (7.5, 'x', 5, 6.9)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[:-1])
# Out:
# (26, 45, 'hello', 7.5, 'x', 5)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[::-1])
# Out:
# (6.9, 5, 'x', 7.5, 'hello', 45, 26)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[::-2])
# Out:
# (6.9, 'x', 'hello', 26)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[::-3])
# Out:
# (6.9, 7.5, 26)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[-3::])
# Out:
# ('x', 5, 6.9)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[2::])
# Out:
# ('hello', 7.5, 'x', 5, 6.9)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[1:4])
# Out:
# (45, 'hello', 7.5)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[1::1])
# Out:
# (45, 'hello', 7.5, 'x', 5, 6.9)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[1::3])
# Out:
# (45, 'x')

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[-1::-2])
# Out:
# (6.9, 'x', 'hello', 26)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[1:6:2])
# Out:
# (45, 7.5, 5)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
print(value_tuple[1:3:2])
# Out:
# (45,)

# %%
value_tuple=(26,45,'hello',7.5,'x',5,6.9)
del(value_tuple)
print()
